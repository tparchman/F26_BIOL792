# %% [markdown]
# ### simple print statement

# %%
print("welcome to jupyter")
# Out:
# welcome to jupyter

# %% [markdown]
# ### Scalar demo, a bit of math

# %%
num1= 7
num2=9
num3=num1 * num2
print(num3)
# Out:
# 63

# %% [markdown]
# ### For loop demo

# %%
Seq="ATTTCCCCCC"
for i in Seq:
    print(i)
# Out:
# A
# T
# T
# T
# C
# C
# C
# C
# C
# C

# %% [markdown]
# ### Input and for loop demo

# %%
IN = open("../grouse_barcodes.csv", 'r')
for line in IN:
    print(line)
# Out:
# BARCODE_ID,BARCODE,ID
#
# index_8nt_2,aacgccaa,PE_PE_1
#
# index_9nt_4,tgaagccaa,PE_PE_2
#
# index_10nt_6,atcggaccaa,PE_PE_3
#
# index_10nt_8,ctgataccaa,PE_PE_4
#
# index_8nt_11,tgagagaa,PE_PE_5
#
# index_8nt_13,ggtaggaa,PE_PE_6
#
# index_8nt_15,ggccataa,PE_PE_7
#
# index_8nt_17,catactaa,PE_PE_8
#
# index_10nt_2,ccagaaccaa,PE_PE_9
#
# index_8nt_5,agacgcaa,PE_PE_10
#
# index_8nt_7,tagatcaa,PE_PE_11
#
# index_9nt_9,aataagcaa,PE_PE_12
#
# index_9nt_11,tcggagcaa,PE_PE_13
#
# index_9nt_13,ccaacgcaa,PE_PE_14
#
# index_9nt_15,atcgcgcaa,PE_PE_15
#
# index_9nt_17,ccttatcaa,PE_PE_16
#
# index_8nt_3,cggtccaa,PE_PE_17
#
# index_9nt_5,aaccgccaa,PE_PE_18
#
# index_9nt_7,ctgatccaa,CO_HC_20
#
# index_10nt_9,accaagccaa,CO_QR_21
#
# index_10nt_11,taggagccaa,CO_QR_22
#
# index_10nt_13,gatacgccaa,CO_QR_24
#
# index_10nt_17,ttaactccaa,CO_QR_25
#
# index_10nt_23,tgcgaagcaa,CO_QR_26
#
# index_9nt_3,aggtaccaa,CO_HC_27
#
# index_10nt_5,tcgcgaccaa,CO_QR_29
#
# index_10nt_7,cattgaccaa,CO_QR_30
#
# index_8nt_10,cagcagaa,CO_HC_31
#
# index_8nt_12,gtctcgaa,CO_HC_32
#
# index_8nt_14,ccatggaa,CO_QR_34
#
# index_8nt_16,atggataa,CO_QR_35
#
# index_8nt_18,ttacctaa,CO_QR_36
#
# index_10nt_3,aggtaaccaa,CO_QR_37
#
# index_8nt_6,tctggcaa,CO_HC_41
#
# index_8nt_8,gttctcaa,CO_HC_42
#
# index_9nt_10,cgccagcaa,CO_HC_43
#
# index_9nt_12,gtatagcaa,CO_QR_44
#
# index_9nt_14,gagccgcaa,CO_HC_45
#
# index_9nt_16,tacttgcaa,CO_QR_46
#
# index_9nt_18,ggtactcaa,CO_HC_47
#
# index_8nt_4,ctcagcaa,CO_HC_48
#
# index_9nt_6,gttggccaa,CO_HC_49
#
# index_9nt_8,tctctccaa,CO_QR_50
#
# index_10nt_10,cgtcagccaa,CO_QR_51
#
# index_10nt_12,gtatagccaa,CO_HC_52
#
# index_10nt_16,tcttatccaa,CO_HC_56
#
# index_10nt_18,gccgctccaa,CO_QR_57
#
# index_10nt_24,taaccagcaa,CO_QR_58
#
# index_8nt_19,gaaggtaa,CO_QR_60
#
# index_9nt_21,gcagttcaa,CO_HC_61
#
# index_10nt_41,ggtccatcaa,CO_HC_62
#
# index_10nt_47,ttacgctcaa,CO_QR_63
#
# index_8nt_28,gtacggca,CO_QR_64
#
# index_8nt_30,gcatatca,CO_HC_65
#
# index_8nt_32,agcagtca,CO_HC_68
#
# index_8nt_34,gcgcaaga,CO_HC_69
#
# index_9nt_19,ttacctcaa,CO_HC_70
#
# index_10nt_37,agcctggcaa,CO_QR_71
#
# index_8nt_24,cgcctcca,CO_HC_72
#
# index_8nt_26,acgccgca,CO_QR_73
#
# index_9nt_28,cgctgagaa,PV_PF_74
#
# index_9nt_30,tagaacgaa,PV_PF_75
#
# index_9nt_32,ggcgccgaa,PV_PF_79
#
# index_9nt_34,ttattcgaa,PV_PF_81
#
# index_10nt_25,cttgcagcaa,PV_GC_83
#
# index_8nt_22,aattacca,PV_PF_85
#
# index_9nt_24,aggccagaa,PV_PF_86
#
# index_9nt_26,gcatcagaa,PV_PF_87
#
# index_10nt_57,ccgtcaagaa,PV_GC_89
#
# index_10nt_59,ctccgaagaa,PV_PF_90
#
# index_10nt_62,ttggtaagaa,PV_DH_92
#
# index_10nt_104,tcctcttgaa,PV_GC_93
#
# index_9nt_20,acgagtcaa,PV_PF_94
#
# index_10nt_38,ggtaatgcaa,PV_DH_95
#
# index_10nt_43,tccatatcaa,PV_DH_96
#
# index_8nt_27,gatgcgca,PV_DH_97
#
# index_8nt_29,cttcatca,PV_PF_99
#
# index_8nt_31,tccgctca,PV_GC_101
#
# index_8nt_33,gagcttca,PV_PF_102
#
# index_9nt_35,ggaatggaa,PV_GC_103
#
# index_10nt_31,agaaccgcaa,PV_PF_105
#
# index_8nt_23,ataatcca,PV_DH_107
#
# index_8nt_25,cgaacgca,PV_GC_108
#
# index_9nt_27,ataagagaa,PV_DH_110
#
# index_9nt_29,tccatagaa,PV_PF_111
#
# index_9nt_31,actgacgaa,PV_GC_112
#
# index_9nt_33,ccgcgcgaa,PV_PF_114
#
# index_10nt_114,tctcgcataa,PV_GC_117
#
# index_8nt_21,gtcgacca,PV_GC_120
#
# index_9nt_23,tgagaagaa,PV_DH_121
#
# index_9nt_25,catgcagaa,PV_DH_122
#
# index_10nt_56,gacgcaagaa,PV_GC_123
#
# index_10nt_58,tcaagaagaa,PV_PF_125
#
# index_10nt_60,ggttgaagaa,PV_DH_127
#
# index_10nt_63,tggaccagaa,PV_PF_128
#
# index_8nt_36,agctaaga,PV_DH_131
#
# index_9nt_36,attctggaa,PV_DH_132
#
# index_9nt_38,ctggatgaa,PV_GC_133
#
# index_9nt_40,cttcaataa,PV_PF_134
#
# index_10nt_151,ataagaacca,PV_PF_135
#
# index_10nt_153,gtcctaacca,PV_GC_136
#
# index_10nt_162,cttattacca,PV_GC_137
#
# index_10nt_165,cagagagcca,PV_DH_138
#
# index_10nt_173,ctatcggcca,PV_PF_139
#
# index_10nt_130,aagttgctaa,PV_GC_140
#
# index_10nt_143,tgcaacttaa,PV_PF_141
#
# index_8nt_41,cttgccga,KV_LM_143
#
# index_8nt_43,acgttcga,KV_LM_147
#
# index_8nt_45,ctgatgga,KV_LM_149
#
# index_8nt_47,actgaata,KV_LM_150
#
# index_8nt_49,gtagcata,KV_LM_151
#
# index_8nt_51,gccttata,KV_KB_152
#
# index_8nt_37,aatccaga,KV_LM_153
#
# index_8nt_39,ggaataga,KV_KB_155
#
# index_9nt_41,aaggaataa,KV_LM_157
#
# index_9nt_43,gatagataa,KV_KB_159
#
# index_9nt_45,gcgctataa,KV_LM_160
#
# index_9nt_47,gtaacctaa,KV_KB_161
#
# index_9nt_49,acctagtaa,KV_LM_162
#
# index_9nt_51,gctgcgtaa,KV_KB_164
#
# index_9nt_37,agcaatgaa,KV_LM_165
#
# index_9nt_39,caacttgaa,KV_LM_168
#
# index_10nt_150,cgctcaacca,KV_KB_172
#
# index_10nt_152,cctcgaacca,KV_LM_173
#
# index_10nt_155,ctgcagacca,KV_KB_176
#
# index_10nt_164,accgttacca,KV_LM_177
#
# index_10nt_167,cattacgcca,KV_KB_178
#
# index_10nt_176,tgagctgcca,KV_LM_179
#
# index_10nt_138,atagtcgtaa,KV_KB_180
#
# index_10nt_148,aagccaacca,KV_KB_181
#
# index_8nt_42,gaccgcga,KV_KB_183
#
# index_8nt_44,tataagga,KV_LM_186
#
# index_8nt_46,tggactga,KV_KB_187
#
# index_8nt_48,tagtaata,KV_LM_189
#
# index_8nt_50,atccgata,KV_LM_190
#
# index_8nt_52,tgctgcta,KV_KB_191
#
# index_8nt_38,cctagaga,KV_LM_192
#
# index_8nt_40,ttcgtaga,KV_KB_193
#
# index_9nt_42,ttctcataa,KV_LM_195
#
# index_9nt_44,ccaggataa,KV_LM_196
#
# index_9nt_46,agattataa,KV_LM_197
#
# index_9nt_48,cagtcctaa,KV_KB_198
#
# index_9nt_50,tggacgtaa,KV_KB_199
#
# index_9nt_52,ctcaggtaa,NC_MM_200
#
# index_10nt_185,acctcgtcca,NC_BP_201
#
# index_8nt_55,aagaggta,NC_BP_202
#
# index_10nt_195,aattggagca,NC_MM_203
#
# index_10nt_211,aactctcgca,NC_BP_204
#
# index_8nt_62,aatataac,NC_BP_205
#
# index_8nt_64,cttaagac,NC_MM_207
#
# index_8nt_66,aggacgac,NC_BP_208
#
# index_8nt_68,cgcttgac,NC_MM_209
#
# index_8nt_53,ccagtcta,NC_MM_210
#
# index_10nt_191,aggcgcagca,NC_BP_212
#
# index_8nt_58,cctccaac,NC_MM_214
#
# index_9nt_60,cctatacca,NC_BP_215
#
# index_9nt_62,actccgcca,NC_MM_217
#
# index_9nt_64,cggaggcca,NC_MM_218
#
# index_9nt_66,gcgttgcca,NC_BP_219
#
# index_9nt_68,gatcgtcca,NC_MM_220
#
# index_9nt_53,taacggtaa,NC_MM_221
#
# index_8nt_56,ttcaatta,NC_BP_222
#
# index_9nt_58,gtcagacca,NC_MM_223
#
# index_10nt_213,aatgcaggca,NC_MM_224
#
# index_10nt_218,ttaattggca,NC_MM_225
#
# index_10nt_222,agaacttgca,NC_BP_226
#
# index_10nt_227,ttatgcatca,NC_MM_227
#
# index_10nt_239,gcttgcctca,NC_MM_228
#
# index_10nt_188,cgaggaagca,NC_MM_229
#
# index_10nt_192,catctcagca,NC_MM_230
#
# index_10nt_200,caggaacgca,NC_BP_231
#
# index_8nt_61,acctgaac,NC_MM_233
#
# index_8nt_63,gcggtaac,NC_BP_234
#
# index_8nt_65,gacgagac,NC_MM_235
#
# index_8nt_67,tattggac,NC_MM_236
#
# index_8nt_69,taggctac,NC_MM_237
#
# index_8nt_54,atatagta,NC_MM_243
#
# index_8nt_57,ccgcgtta,HA_HA_244
#
# index_8nt_59,ttgcgaac,HA_HA_245
#
# index_9nt_61,cttgagcca,HA_HA_246
#
# index_9nt_63,ggagcgcca,HA_HA_247
#
# index_9nt_65,ataatgcca,HA_HA_250
#
# index_9nt_67,tagactcca,HA_HA_251
#
# index_9nt_69,ctccttcca,HA_HA_252
#
# index_9nt_54,aatccttaa,HA_HA_253
#
# index_9nt_57,ggttaacca,HA_HA_254
#
# index_9nt_59,agacgacca,HA_HA_255
#
# index_10nt_215,ttggacggca,HA_HA_256
#
# index_10nt_221,cataattgca,HA_HA_257
#
# index_10nt_225,caattaatca,HA_HA_258
#
# index_10nt_231,tattctatca,HA_HA_259
#
# index_10nt_243,agcatgctca,HA_HA_260

# %% [markdown]
# # Header
# ## subheader
# ### subsub
#
# normal text just looks like this.
#
# - list
# - list
#
# Below is a way to specify a code box in markdown. Note, if you specify a code box like this, it wont be active as in the other jupyter code boxes.
#
# ```python
# FileName=open("yaya.txt")
#
# ```

# %% [markdown]
# ## here I am going to write a for loop
# - weather
# - time
# - space

# %%
ctr=0
for i in Seq:
    ctr += 1
    print(ctr, "base is: ", i)
# Out:
# 1 base is:  A
# 2 base is:  T
# 3 base is:  T
# 4 base is:  T
# 5 base is:  C
# 6 base is:  C
# 7 base is:  C
# 8 base is:  C
# 9 base is:  C
# 10 base is:  C

# %% [markdown]
# ## illustrating linux commands in jupyter
#
# Using `%` (or `!`) before commands allows executing of linux commands in jupyter notebooks. Play with this, and you will realize that `tab` autocomplete works as well. So, magically, you can navigate your file system and run linux commands within jupyter notebooks. This means that you can hop back and forth between linux and python if you desire to do so. It also means that jupyter notebooks offer a mechanism for documenting linux code that you find repeatably useful, or for keeping a record of linux commands that are useful for you.

# %%
# %ls
# Out:
# demo.ipynb                  jupyter_getting_started.md
# images/                     new.ipynb

# %%
# %cd ../
# %pwd
# Out:
# /Users/thomasparchman/Documents/GitHub/F23_BIOL792/week5
# '/Users/thomasparchman/Documents/GitHub/F23_BIOL792/week5'

# %%
# %cp demo.ipynb new.ipynb
# %ls
# Out:
# demo.ipynb                  jupyter_getting_started.md
# images/                     new.ipynb
